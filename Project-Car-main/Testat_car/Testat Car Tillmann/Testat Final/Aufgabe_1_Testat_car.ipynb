# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_max = 4.5
x_min = 0
y_max = 3.5
y_min = -2
x_pts = np.array([1, 2, 3, 4])
y_pts = np.array([1, 2, 3, 1])

A = np.array([[1, 1, 1**2, 1**3],
              [1, 2, 2**2, 2**3],
              [1, 3, 3**2, 3**3],
              [1, 4, 4**2, 4**3]])

coeffs = np.linalg.solve(A, y_pts)

def f(x, b):
    return b[0] + b[1]*x + b[2]*x**2 + b[3]*x**3 

x = np.linspace(x_min, x_max, 1000)
y = f(x, coeffs)

fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(x, y, 'b-', linewidth=2)
ax.plot(x_pts, y_pts, 'r*', markersize=8)

ax.set_xticks(np.arange(x_min, x_max + 1, 1))
ax.set_yticks(np.arange(y_min, y_max, 1))
ax.set_xticks(np.arange(x_min + 0.5, x_max, 1.0), minor=True)
ax.set_yticks(np.arange(y_min + 0.5, y_max, 1.0), minor=True)
ax.grid(True, which='major', alpha=0.6)
ax.grid(True, which='minor', linewidth=0.4, linestyle='--', alpha=0.4)
ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)
ax.set_aspect('equal')
plt.tight_layout()
plt.show()
